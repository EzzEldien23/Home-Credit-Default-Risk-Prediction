# %% [markdown]
# # Home Credit experiment runner
#
# Production feature engineering, training, and prediction code now lives in `src/`. Use this notebook for experiments only, such as overriding `params.yaml` values or inspecting outputs.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import load_training_config
from src.features import build_feature_frame
from src.modeling.train import train_pipeline

# %%
config = load_training_config(PROJECT_ROOT / "params.yaml")
config

# %% [markdown]
# For a quick experiment, edit `params.yaml` row limits or override `config.row_limits` here. Use `None` to load all rows for a table.

# %%
# Example quick experiment:
# config.row_limits["bureau"] = 10000
# config.row_limits["bureau_balance"] = 10000
# train_features, test_features = build_feature_frame(config)
# train_features.shape, test_features.shape

# %%
# Run the full configured pipeline from the notebook if needed.
# Prefer `dvc repro` or `python -m src.modeling.train --params params.yaml` for reproducible runs.
# metrics = train_pipeline(PROJECT_ROOT / "params.yaml")
# metrics
